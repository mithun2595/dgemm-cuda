# %%
ops1 = [0,1.63,6.04,10]
gflops = [0,390.7,1450,1450]
ops2 = [0,2.53,9.41,15]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.title("Roofline model (Actual BW=154GB/s)",fontsize=16)
plt.xlabel("ops/byte",fontsize=16)
plt.ylabel("GFlops/sec",fontsize=16)
plt.plot(ops2,gflops,'g')
plt.xticks(ops2)
plt.yticks(gflops)
plt.grid(True)
plt.savefig("154roofline.png",dip=100)
plt.show()
